# %%
from PIL import Image
# membuka dan menampilkan gambar
import matplotlib.pyplot as plt 
import numpy as np
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drrive')
# Out:
# Mounted at /content/drrive

# %%
image1 = Image.open('/content/drrive/MyDrive/Data/uas/train/Sirih/Sirih001.jpg')
image2 = Image.open('/content/drrive/MyDrive/Data/uas/train/Nangka/Nangka001.jpg')

# %%
# DISPLAY IMAGE 1
plt.imshow(image1)

# %%
# DISPLAY IMAGE 2
plt.imshow(image2)

# %%
newsize = (200, 200)
plt.figure(figsize=(15,15))
resized_image1=image1.resize(newsize, Image.BILINEAR)
resized_image2=image1.resize(newsize, Image.NEAREST)
resized_image3=image1.resize(newsize, Image.BOX)
resized_image4=image1.resize(newsize, Image.HAMMING)
resized_image5=image1.resize(newsize, Image.BICUBIC)
resized_image6=image1.resize(newsize, Image.LANCZOS)
# plt.figure(figsize=(15,15))
plt.subplot(3,2,1)
plt.imshow(resized_image1)
plt.title("BILINEAR")
plt.subplot(3,2,2)
plt.imshow(resized_image2)
plt.title("NEAREST")
plt.subplot(3,2,3)
plt.imshow(resized_image3)
plt.title("Box")
plt.subplot(3,2,4)
plt.imshow(resized_image4)
plt.title("HAMMING")
plt.subplot(3,2,5)
plt.imshow(resized_image5)
plt.title("BICUBIC")
plt.subplot(3,2,6)
plt.imshow(resized_image6)
plt.title("LANCZOS")
# Out:
# Text(0.5, 1.0, 'LANCZOS')

# %%
newsize = (200, 200)
plt.figure(figsize=(15,15))
resized_image1=image2.resize(newsize, Image.BILINEAR)
resized_image2=image2.resize(newsize, Image.NEAREST)
resized_image3=image2.resize(newsize, Image.BOX)
resized_image4=image2.resize(newsize, Image.HAMMING)
resized_image5=image2.resize(newsize, Image.BICUBIC)
resized_image6=image2.resize(newsize, Image.LANCZOS)
# plt.figure(figsize=(15,15))
plt.subplot(3,2,1)
plt.imshow(resized_image1)
plt.title("BILINEAR")
plt.subplot(3,2,2)
plt.imshow(resized_image2)
plt.title("NEAREST")
plt.subplot(3,2,3)
plt.imshow(resized_image3)
plt.title("Box")
plt.subplot(3,2,4)
plt.imshow(resized_image4)
plt.title("HAMMING")
plt.subplot(3,2,5)
plt.imshow(resized_image5)
plt.title("BICUBIC")
plt.subplot(3,2,6)
plt.imshow(resized_image6)
plt.title("LANCZOS")
# Out:
# Text(0.5, 1.0, 'LANCZOS')

# %%
from matplotlib import image
# Setelah DI transpose

print("gambar setelah di transpose")

transpose_image1=image1.transpose(Image.FLIP_LEFT_RIGHT)
transpose_image2=image1.transpose(Image.FLIP_TOP_BOTTOM)
transpose_image3=image1.transpose(Image.ROTATE_90)
transpose_image4=image1.transpose(Image.ROTATE_180)
transpose_image5=image1.transpose(Image.ROTATE_270)
transpose_image6=image1.transpose(Image.TRANSPOSE)
plt.figure(figsize=(15,15))
plt.subplot(3,2,1)
plt.imshow(transpose_image1)
plt.title("FLIP_LEFT RIGHT")
plt.subplot(3,2,2)
plt.imshow(transpose_image2)
plt.title("FLIP_TOP_BOTTOM")
plt.subplot(3,2,3)
plt.imshow(transpose_image3)
plt.title("ROTATE_90")
plt.subplot(3,2,4)
plt.imshow(transpose_image4)
plt.title("ROTATE_180")
plt.subplot(3,2,5)
plt.imshow(transpose_image5)
plt.title("ROTATE_270")
plt.subplot(3,2,6)
plt.imshow(transpose_image6)
plt.title("TRANSPOSE")
# Out:
# gambar setelah di transpose
# Text(0.5, 1.0, 'TRANSPOSE')

# %%
# Setelah DI transpose

print("gambar setelah di transpose")

transpose_image1=image2.transpose(Image.FLIP_LEFT_RIGHT)
transpose_image2=image2.transpose(Image.FLIP_TOP_BOTTOM)
transpose_image3=image2.transpose(Image.ROTATE_90)
transpose_image4=image2.transpose(Image.ROTATE_180)
transpose_image5=image2.transpose(Image.ROTATE_270)
transpose_image6=image2.transpose(Image.TRANSPOSE)
plt.figure(figsize=(15,15))
plt.subplot(3,2,1)
plt.imshow(transpose_image1)
plt.title("FLIP_LEFT RIGHT")
plt.subplot(3,2,2)
plt.imshow(transpose_image2)
plt.title("FLIP_TOP_BOTTOM")
plt.subplot(3,2,3)
plt.imshow(transpose_image3)
plt.title("ROTATE_90")
plt.subplot(3,2,4)
plt.imshow(transpose_image4)
plt.title("ROTATE_180")
plt.subplot(3,2,5)
plt.imshow(transpose_image5)
plt.title("ROTATE_270")
plt.subplot(3,2,6)
plt.imshow(transpose_image6)
plt.title("TRANSPOSE")
# Out:
# gambar setelah di transpose
# Text(0.5, 1.0, 'TRANSPOSE')

# %%
plt.figure(figsize=(15,15))

im_l = image1.convert('L')
im_p = image1.convert('P')

plt.subplot(3,1,1)
plt.imshow(image1)
plt.subplot(3,1,2)
plt.imshow(im_l)
plt.subplot(3,1,3)
plt.imshow(im_p)

# %%
plt.figure(figsize=(15,15))

im_l = image2.convert('L')
im_p = image2.convert('P')

plt.subplot(3,1,1)
plt.imshow(image2)
plt.subplot(3,1,2)
plt.imshow(im_l)
plt.subplot(3,1,3)
plt.imshow(im_p)

# %%
from PIL import ImageEnhance
plt.figure(figsize=(15,15))
image_color_enhan = image1.copy()
image1 = ImageEnhance.Color(image_color_enhan).enhance(2.0)
image2 = ImageEnhance.Contrast(image_color_enhan).enhance(2.0)
image3 = ImageEnhance.Brightness(image_color_enhan).enhance(2.0)
image4 = ImageEnhance.Sharpness(image_color_enhan).enhance(2.0)
plt.subplot(2,2,1)
plt.imshow(image1)
plt.title("Color")
plt.subplot(2,2,2)
plt.imshow(image2)
plt.title("Contrast")
plt.subplot(2,2,3)
plt.imshow(image3)
plt.title("Brightness")
plt.subplot(2,2,4)
plt.imshow(image4)
plt.title("Sharpness")
# Out:
# Text(0.5, 1.0, 'Sharpness')
